# %% [markdown]
# # Infor
#
# Plot the results (seq_bhgpr, lh_vhgpr, lh_sgp) of 2d function.

# %%
import sys
sys.path.append("../../")

# %%
from core import VHGPR
from core import plot_results

# %%
plot_results(None, (0.0,0.08), (60, 120), whether_save=False)
